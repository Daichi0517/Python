# %% [markdown]
# <a href="https://colab.research.google.com/github/Daichi0517/Python/blob/main/FILES.2/MLtest6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
iris = datasets.load_iris()
df = pd.DataFrame(iris.data)
#列名を設定
df.columns = iris.feature_names
df["target"] = iris.target
#3種類の品種を別々のデータフレームに分ける
df0 = df[df["target"]==0]
df1 = df[df["target"]==1]
df2 = df[df["target"]==2]

#3種類の品種をヒストグラムで色分け
plt.figure(figsize=(5,5))
xx = "sepal width (cm)"
df0[xx].hist(color='b',alpha=0.5)
df1[xx].hist(color='r',alpha=0.5)
df2[xx].hist(color='g',alpha=0.5)
plt.show()
